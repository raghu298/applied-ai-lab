# %%
# !!pip install language_tool_python
# Out:
# ['Collecting language_tool_python',
#  '  Obtaining dependency information for language_tool_python from https://files.pythonhosted.org/packages/3a/02/1fc1cd6bfbdaddb31f6466eb9db9aacee30b37cd39ff9b067d34ca20a51a/language_tool_python-2.9.4-py3-none-any.whl.metadata',
#  '  Downloading language_tool_python-2.9.4-py3-none-any.whl.metadata (55 kB)',
#  '     ---------------------------------------- 0.0/55.5 kB ? eta -:--:--',
#  '     ------- -------------------------------- 10.2/55.5 kB ? eta -:--:--',
#  '     ------- -------------------------------- 10.2/55.5 kB ? eta -:--:--',
#  '     ----------------------------------- -- 51.2/55.5 kB 440.4 kB/s eta 0:00:01',
#  '     ----------------------------------- -- 51.2/55.5 kB 440.4 kB/s eta 0:00:01',
#  '     -------------------------------------- 55.5/55.5 kB 242.2 kB/s eta 0:00:00',
#  'Requirement already satisfied: requests in c:\\users\\admin\\anaconda3\\lib\\site-packages (from language_tool_python) (2.31.0)',
#  'Requirement already satisfied: tqdm in c:\\users\\admin\\anaconda3\\lib\\site-packages (from language_tool_python) (4.65.0)',
#  'Requirement already satisfied: psutil in c:\\users\\admin\\anaconda3\\lib\\site-packages (from language_tool_python) (5.9.0)',
#  'Requirement already satisfied: toml in c:\\users\\admin\\anaconda3\\lib\\site-packages (from language_tool_python) (0.10.2)',
#  'Requirement already satisfied: charset-normalizer<4,>=2 in c:\\users\\admin\\anaconda3\\lib\\site-packages (from requests->language_tool_python) (2.0.4)',
#  'Requirement already satisfied: idna<4,>=2.5 in c:\\users\\admin\\anaconda3\\lib\\site-packages (from requests->language_tool_python) (3.4)',
#  'Requirement already satisfied: urllib3<3,>=1.21.1 in c:\\users\\admin\\anaconda3\\lib\\site-packages (from requests->language_tool_python) (1.26.16)',
#  'Requirement already satisfied: certifi>=2017.4.17 in c:\\users\\admin\\anaconda3\\lib\\site-packages (from requests->language_tool_python) (2023.7.22)',
#  'Requirement already satisfied: colorama in c:\\users\\admin\\anaconda3\\lib\\site-packages (from tqdm->language_tool_python) (0.4.6)',
#  'Downloading language_tool_python-2.9.4-py3-none-any.whl (55 kB)',
#  '   ---------------------------------------- 0.0/55.6 kB ? eta -:--:--',
#  '   ------------------------------------ --- 51.2/55.6 kB 1.3 MB/s eta 0:00:01',
#  '   ---------------------------------------- 55.6/55.6 kB 731.3 kB/s eta 0:00:00',
#  'Installing collected packages: language_tool_python',
#  'Successfully installed language_tool_python-2.9.4']

# %%
import language_tool_python

# This will download and run the LanguageTool server
tool = language_tool_python.LanguageTool('en-US')

text = "I havv goood speling and i went two the store."
matches = tool.check(text)

print(f"Found {len(matches)} errors.")

# Apply the corrections
corrected_text = tool.correct(text)
print(corrected_text)

# Output:
# Found 4 errors.
# I have good spelling and I went to the store.
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Cell In[1], line 4
#       1 import language_tool_python
#       3 # This will download and run the LanguageTool server
# ----> 4 tool = language_tool_python.LanguageTool('en-US')
#       6 text = "I havv goood speling and i went two the store."
#       7 matches = tool.check(text)
#
# File ~\anaconda3\Lib\site-packages\language_tool_python\server.py:121, in LanguageTool.__init__(self, language, motherTongue, remote_server, newSpellings, new_spellings_persist, host, config, language_tool_download_version)
#     119 elif not self._server_is_alive():
#     120     self._stop_consume_event = threading.Event()
# --> 121     self._start_server_on_free_port()
#     122 if language is None:
#     123     try:
#
# File ~\anaconda3\Lib\site-packages\language_tool_python\server.py:513, in LanguageTool._start_server_on_free_port(self)
#     511 self._url = f'http://{self._host}:{self._port}/v2/'
#     512 try:
# --> 513     self._start_local_server()
#     514     break
#     515 except ServerError:
#
# File ~\anaconda3\Lib\site-packages\language_tool_python\server.py:539, in LanguageTool._start_local_server(self)
#     522 """
#     523 Start the local LanguageTool server.
#     524 This method starts a local instance of the LanguageTool server. If the
#    (...)
#     536 :raises ServerError: If the server is already running or cannot be started.
#     537 """
#     538 # Before starting local server, download language tool if needed.
# --> 539 download_lt(self.language_tool_download_version)
#     540 err = None
#     541 try:
#
# File ~\anaconda3\Lib\site-packages\language_tool_python\download_lt.py:211, in download_lt(language_tool_version)
#     196 def download_lt(language_tool_version: Optional[str] = LTP_DOWNLOAD_VERSION) -> None:
#     197     """
#     198     Downloads and extracts the specified version of LanguageTool.
#     199     This function checks for Java compatibility, creates the necessary download
#    (...)
#     208     :raises ValueError: If the specified version format is invalid.
#     209     """
# --> 211     confirm_java_compatibility(language_tool_version)
#     213     download_folder = get_language_tool_download_path()
#     215     # Use the env var to the jar directory if it is defined
#     216     # otherwise look in the download directory
#
# File ~\anaconda3\Lib\site-packages\language_tool_python\download_lt.py:113, in confirm_java_compatibility(language_tool_version)
#     111 else:
#     112     if (major_version == 1 and minor_version < 17) or (major_version != 1 and major_version < 17):
# --> 113         raise SystemError(f'Detected java {major_version}.{minor_version}. LanguageTool requires Java >= 17 for version {language_tool_version}.')
#
# SystemError: Detected java 1.8. LanguageTool requires Java >= 17 for version latest.
