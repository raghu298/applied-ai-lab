# %%
# !pip install pyspellchecker
# Out:
# Requirement already satisfied: pyspellchecker in c:\users\admin\anaconda3\lib\site-packages (0.7.2)

# %%
from spellchecker import SpellChecker
 
spell = SpellChecker()
 
# find those words that may be misspelled
misspelled = spell.unknown(["cmputr", "watr", "study", "wrte"])
 
for word in misspelled:
    # Get the one `most likely` answer
    print(spell.correction(word))
 
    # Get a list of `likely` options
    print(spell.candidates(word))
# Out:
# water
# {'war', 'water', 'wart', 'wat', 'watt'}
# write
# {'write', 'wre', 'wite', 'wrote'}
# computer
# {'impute', 'compute', 'computer'}
